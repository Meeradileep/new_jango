# %% [markdown]
# <a href="https://colab.research.google.com/github/Meeradileep/new_jango/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
name1 = input("Enter your name ")
name2 = input("Enter his or her name ")
score = random.randint(0,100)
print(f"\n love between {name1} and {name2} is {score}%")
if score < 35:
  print ("no chance")
elif (score >= 35 and score < 50) :
  print ("Fine")

elif (score >=50 and score < 80):
  print("Perfect match")

else:
  print("fixed marrage")

# %%
print("Welcome to Reva ATH")

balance=0

pin = int(input("Set the pin"))

entred_pin = int(input("Enter your pin to contiune"))

if(entred_pin == pin):
  print("Login Successfull")

while True:
  print("1.Deposit")
  print("2.Check Balanace")
  print("3.WithDraw")
  print("4.Exit")

  choice= int(input("Enter your choice"))

  if choice==1:
             amount = int(input("Enter the amount to Deposite"))
             balance += amount
             print("Money Deposited")

  elif choice==2:
             print("Your balance is", balance)
  elif(choice ==3):
    amount =int(input("Enter amount to withdraw:  "))
    if amount<=balance:
      balance -= amount
      print("Please collect your cash!")
    else:
      print("Insufficient balance!")

  elif choice == 4:
      print(" Thank you for using ATM")
      break

  else:
    print("Invalide Choice")

else:
  print("Wrong pin")
# Out:
# Welcome to Reva ATH
# Set the pin1250
# Enter your pin to contiune1250
# Login Successfull
# 1.Deposit
# 2.Check Balanace
# 3.WithDraw
# 4.Exit
# Enter your choice2
# Your balance is 0
# 1.Deposit
# 2.Check Balanace
# 3.WithDraw
# 4.Exit
# Enter your choice1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1905172156.py in <cell line: 0>()
#      19
#      20   if choice==1:
# ---> 21              amount = int(input("Enter the amount to Deposite"))
#      22              balance += amount
#      23              print("Money Deposited")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...

# %% [markdown]
#   NUMPY--Numerical
#   python
#
#   uses of numpy
#   arithematical operation

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr = np.array([[1,2],[3,4]])
print(arr)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr = np.zeros((2,3))
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
arr = np.ones((2,3))*5
print(arr)
# Out:
# [[5. 5. 5.]
#  [5. 5. 5.]]

# %%
arr = np.arange(5,15,2)
print(arr)
# Out:
# [ 5  7  9 11 13]

# %%
arr = np.eye(3)*3
print(arr)
# Out:
# [[3. 0. 0.]
#  [0. 3. 0.]
#  [0. 0. 3.]]
